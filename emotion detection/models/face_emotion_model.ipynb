# %%
import numpy as np
import os
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, BatchNormalization
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
train_dir = "X:/emotion_dataset/train/"
val_dir = "X:/emotion_dataset/test/"
model_save_path = os.path.join("..", "models", "face_emotion_model.h5")

# --- Data Augmentation ---
train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=15,
    width_shift_range=0.1,
    height_shift_range=0.1,
    zoom_range=0.1,
    horizontal_flip=True
)

val_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(48, 48),
    color_mode='grayscale',
    class_mode='categorical',
    batch_size=32,
    shuffle=True
)

val_generator = val_datagen.flow_from_directory(
    val_dir,
    target_size=(48, 48),
    color_mode='grayscale',
    class_mode='categorical',
    batch_size=32,
    shuffle=False
)
# Out:
# Found 28709 images belonging to 7 classes.
# Found 7178 images belonging to 7 classes.

# %%
model = Sequential([
    Conv2D(32, (3,3), activation='relu', input_shape=(48,48,1)),
    BatchNormalization(),
    MaxPooling2D(2,2),
    Dropout(0.2),

    Conv2D(64, (3,3), activation='relu'),
    BatchNormalization(),
    MaxPooling2D(2,2),
    Dropout(0.25),

    Conv2D(128, (3,3), activation='relu'),
    BatchNormalization(),
    MaxPooling2D(2,2),
    Dropout(0.3),

    Flatten(),
    Dense(128, activation='relu'),
    BatchNormalization(),
    Dropout(0.4),

    Dense(train_generator.num_classes, activation='softmax')
])

model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
# Out:
# C:\Users\NILOY CHOWDHURY\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
checkpoint = ModelCheckpoint(filepath=model_save_path, save_best_only=True, monitor='val_accuracy', mode='max')
early_stop = EarlyStopping(monitor='val_accuracy', patience=15, restore_best_weights=True)

# %%
model.fit(
    train_generator,
    epochs=100,  # reduced, rely on early stopping
    validation_data=val_generator,
    callbacks=[checkpoint, early_stop]
)
# Out:
# C:\Users\NILOY CHOWDHURY\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/100
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 0s 241ms/step - accuracy: 0.2157 - loss: 2.2351
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 267s 294ms/step - accuracy: 0.2157 - loss: 2.2348 - val_accuracy: 0.3302 - val_loss: 1.6446
# Epoch 2/100
# 897/898 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.3233 - loss: 1.6965
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 46s 52ms/step - accuracy: 0.3233 - loss: 1.6964 - val_accuracy: 0.3977 - val_loss: 1.5159
# Epoch 3/100
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.3951 - loss: 1.5575
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 46s 51ms/step - accuracy: 0.3951 - loss: 1.5575 - val_accuracy: 0.4784 - val_loss: 1.3666
# Epoch 4/100
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 46s 51ms/step - accuracy: 0.4358 - loss: 1.4657 - val_accuracy: 0.4772 - val_loss: 1.3717
# Epoch 5/100
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 46s 51ms/step - accuracy: 0.4607 - loss: 1.4222 - val_accuracy: 0.4674 - val_loss: 1.4019
# Epoch 6/100
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.4555 - loss: 1.4016
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 49s 55ms/step - accuracy: 0.4555 - loss: 1.4016 - val_accuracy: 0.5226 - val_loss: 1.2317
# Epoch 7/100
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 48s 53ms/step - accuracy: 0.4757 - loss: 1.3752 - val_accuracy: 0.4979 - val_loss: 1.3201
# Epoch 8/100
# 897/898 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.4828 - loss: 1.3600
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 49s 55ms/step - accuracy: 0.4828 - loss: 1.3600 - val_accuracy: 0.5482 - val_loss: 1.1902
# Epoch 9/100
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 50s 56ms/step - accuracy: 0.4933 - loss: 1.3309 - val_accuracy: 0.5369 - val_loss: 1.2033
# Epoch 10/100
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 50s 55ms/step - accuracy: 0.4996 - loss: 1.3190 - val_accuracy: 0.5091 - val_loss: 1.2782
# Epoch 11/100
# 897/898 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.4969 - loss: 1.3129
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 50s 56ms/step - accuracy: 0.4970 - loss: 1.3129 - val_accuracy: 0.5584 - val_loss: 1.1654
# Epoch 12/100
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 55s 61ms/step - accuracy: 0.5035 - loss: 1.3011 - val_accuracy: 0.5294 - val_loss: 1.2232
# Epoch 13/100
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.5103 - loss: 1.2835
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 50s 56ms/step - accuracy: 0.5103 - loss: 1.2835 - val_accuracy: 0.5733 - val_loss: 1.1196
# Epoch 14/100
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 51s 57ms/step - accuracy: 0.5140 - loss: 1.2775 - val_accuracy: 0.5550 - val_loss: 1.1578
# Epoch 15/100
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 54s 60ms/step - accuracy: 0.5221 - loss: 1.2571 - val_accuracy: 0.5306 - val_loss: 1.2098
# Epoch 16/100
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 49s 55ms/step - accuracy: 0.5188 - loss: 1.2586 - val_accuracy: 0.5341 - val_loss: 1.1977
# Epoch 17/100
# 897/898 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.5285 - loss: 1.2545
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 48s 53ms/step - accuracy: 0.5285 - loss: 1.2545 - val_accuracy: 0.5775 - val_loss: 1.1052
# Epoch 18/100
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 50s 55ms/step - accuracy: 0.5262 - loss: 1.2510 - val_accuracy: 0.5468 - val_loss: 1.1665
# Epoch 19/100
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 51s 57ms/step - accuracy: 0.5259 - loss: 1.2524 - val_accuracy: 0.5704 - val_loss: 1.1180
# Epoch 20/100
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 55s 61ms/step - accuracy: 0.5342 - loss: 1.2271 - val_accuracy: 0.5729 - val_loss: 1.1090
# Epoch 21/100
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 58s 65ms/step - accuracy: 0.5291 - loss: 1.2481 - val_accuracy: 0.5582 - val_loss: 1.1585
# Epoch 22/100
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 56s 62ms/step - accuracy: 0.5354 - loss: 1.2215 - val_accuracy: 0.5149 - val_loss: 1.2575
# Epoch 23/100
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 56s 62ms/step - accuracy: 0.5402 - loss: 1.2175 - val_accuracy: 0.5502 - val_loss: 1.1796
# Epoch 24/100
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 51s 57ms/step - accuracy: 0.5411 - loss: 1.2179 - val_accuracy: 0.5761 - val_loss: 1.1109
# Epoch 25/100
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 51s 57ms/step - accuracy: 0.5345 - loss: 1.2086 - val_accuracy: 0.5571 - val_loss: 1.1665
# Epoch 26/100
# 897/898 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.5440 - loss: 1.2010
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 52s 58ms/step - accuracy: 0.5440 - loss: 1.2010 - val_accuracy: 0.5854 - val_loss: 1.0933
# Epoch 27/100
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 51s 56ms/step - accuracy: 0.5458 - loss: 1.2004 - val_accuracy: 0.5846 - val_loss: 1.0855
# Epoch 28/100
# 897/898 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.5474 - loss: 1.1941
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 51s 56ms/step - accuracy: 0.5474 - loss: 1.1941 - val_accuracy: 0.5864 - val_loss: 1.0799
# Epoch 29/100
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 51s 57ms/step - accuracy: 0.5508 - loss: 1.1941 - val_accuracy: 0.5156 - val_loss: 1.2656
# Epoch 30/100
# 897/898 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.5312 - loss: 1.2291
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 52s 58ms/step - accuracy: 0.5312 - loss: 1.2290 - val_accuracy: 0.5892 - val_loss: 1.0738
# Epoch 31/100
# 897/898 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.5473 - loss: 1.1926
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 52s 58ms/step - accuracy: 0.5473 - loss: 1.1926 - val_accuracy: 0.6084 - val_loss: 1.0459
# Epoch 32/100
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 51s 57ms/step - accuracy: 0.5497 - loss: 1.1841 - val_accuracy: 0.5981 - val_loss: 1.0606
# Epoch 33/100
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 51s 57ms/step - accuracy: 0.5475 - loss: 1.1957 - val_accuracy: 0.5999 - val_loss: 1.0565
# Epoch 34/100
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 52s 58ms/step - accuracy: 0.5527 - loss: 1.1774 - val_accuracy: 0.5928 - val_loss: 1.0726
# Epoch 35/100
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 53s 59ms/step - accuracy: 0.5608 - loss: 1.1675 - val_accuracy: 0.5971 - val_loss: 1.0581
# Epoch 36/100
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 53s 59ms/step - accuracy: 0.5504 - loss: 1.1778 - val_accuracy: 0.6070 - val_loss: 1.0397
# Epoch 37/100
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 54s 61ms/step - accuracy: 0.5485 - loss: 1.1940 - val_accuracy: 0.5351 - val_loss: 1.2218
# Epoch 38/100
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 52s 58ms/step - accuracy: 0.5520 - loss: 1.1844 - val_accuracy: 0.5886 - val_loss: 1.0836
# Epoch 39/100
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.5629 - loss: 1.1687
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 50s 56ms/step - accuracy: 0.5629 - loss: 1.1687 - val_accuracy: 0.6169 - val_loss: 1.0214
# Epoch 40/100
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 50s 56ms/step - accuracy: 0.5574 - loss: 1.1675 - val_accuracy: 0.5943 - val_loss: 1.0648
# Epoch 41/100
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 46s 51ms/step - accuracy: 0.5647 - loss: 1.1590 - val_accuracy: 0.5793 - val_loss: 1.0738
# Epoch 42/100
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 46s 51ms/step - accuracy: 0.5626 - loss: 1.1600 - val_accuracy: 0.5889 - val_loss: 1.0788
# Epoch 43/100
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 46s 51ms/step - accuracy: 0.5599 - loss: 1.1703 - val_accuracy: 0.6138 - val_loss: 1.0347
# Epoch 44/100
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 46s 51ms/step - accuracy: 0.5537 - loss: 1.1795 - val_accuracy: 0.5804 - val_loss: 1.1122
# Epoch 45/100
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 46s 51ms/step - accuracy: 0.5613 - loss: 1.1557 - val_accuracy: 0.6059 - val_loss: 1.0387
# Epoch 46/100
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 46s 51ms/step - accuracy: 0.5601 - loss: 1.1618 - val_accuracy: 0.6085 - val_loss: 1.0346
# Epoch 47/100
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 46s 51ms/step - accuracy: 0.5629 - loss: 1.1600 - val_accuracy: 0.5511 - val_loss: 1.1689
# Epoch 48/100
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 47s 52ms/step - accuracy: 0.5663 - loss: 1.1553 - val_accuracy: 0.5957 - val_loss: 1.0524
# Epoch 49/100
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 49s 54ms/step - accuracy: 0.5666 - loss: 1.1505 - val_accuracy: 0.5808 - val_loss: 1.1162
# Epoch 50/100
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 47s 53ms/step - accuracy: 0.5662 - loss: 1.1473 - val_accuracy: 0.5709 - val_loss: 1.1149
# Epoch 51/100
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 47s 52ms/step - accuracy: 0.5652 - loss: 1.1504 - val_accuracy: 0.6087 - val_loss: 1.0419
# Epoch 52/100
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.5689 - loss: 1.1454
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 47s 52ms/step - accuracy: 0.5689 - loss: 1.1454 - val_accuracy: 0.6233 - val_loss: 1.0107
# Epoch 53/100
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 46s 52ms/step - accuracy: 0.5632 - loss: 1.1491 - val_accuracy: 0.6089 - val_loss: 1.0392
# Epoch 54/100
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 47s 52ms/step - accuracy: 0.5684 - loss: 1.1474 - val_accuracy: 0.6088 - val_loss: 1.0320
# Epoch 55/100
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 46s 51ms/step - accuracy: 0.5641 - loss: 1.1494 - val_accuracy: 0.6222 - val_loss: 1.0120
# Epoch 56/100
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 46s 51ms/step - accuracy: 0.5711 - loss: 1.1475 - val_accuracy: 0.5860 - val_loss: 1.0931
# Epoch 57/100
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 46s 51ms/step - accuracy: 0.5689 - loss: 1.1347 - val_accuracy: 0.6127 - val_loss: 1.0368
# Epoch 58/100
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 46s 51ms/step - accuracy: 0.5720 - loss: 1.1379 - val_accuracy: 0.5865 - val_loss: 1.0988
# Epoch 59/100
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 46s 51ms/step - accuracy: 0.5715 - loss: 1.1455 - val_accuracy: 0.5988 - val_loss: 1.0655
# Epoch 60/100
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 46s 51ms/step - accuracy: 0.5726 - loss: 1.1406 - val_accuracy: 0.6010 - val_loss: 1.0630
# Epoch 61/100
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 46s 51ms/step - accuracy: 0.5747 - loss: 1.1405 - val_accuracy: 0.5798 - val_loss: 1.1042
# Epoch 62/100
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 46s 52ms/step - accuracy: 0.5716 - loss: 1.1302 - val_accuracy: 0.6172 - val_loss: 1.0045
# Epoch 63/100
# 897/898 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.5814 - loss: 1.1177
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 46s 51ms/step - accuracy: 0.5814 - loss: 1.1177 - val_accuracy: 0.6236 - val_loss: 1.0098
# Epoch 64/100
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 45s 51ms/step - accuracy: 0.5708 - loss: 1.1365 - val_accuracy: 0.6219 - val_loss: 1.0057
# Epoch 65/100
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 46s 51ms/step - accuracy: 0.5769 - loss: 1.1171 - val_accuracy: 0.5986 - val_loss: 1.0508
# Epoch 66/100
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 46s 51ms/step - accuracy: 0.5760 - loss: 1.1203 - val_accuracy: 0.5974 - val_loss: 1.0691
# Epoch 67/100
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 46s 51ms/step - accuracy: 0.5669 - loss: 1.1385 - val_accuracy: 0.6211 - val_loss: 1.0059
# Epoch 68/100
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 46s 51ms/step - accuracy: 0.5764 - loss: 1.1259 - val_accuracy: 0.6028 - val_loss: 1.0454
# Epoch 69/100
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 46s 51ms/step - accuracy: 0.5795 - loss: 1.1197 - val_accuracy: 0.6208 - val_loss: 1.0080
# Epoch 70/100
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 46s 51ms/step - accuracy: 0.5775 - loss: 1.1184 - val_accuracy: 0.5610 - val_loss: 1.1891
# Epoch 71/100
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 46s 51ms/step - accuracy: 0.5755 - loss: 1.1217 - val_accuracy: 0.5925 - val_loss: 1.0729
# Epoch 72/100
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 46s 51ms/step - accuracy: 0.5784 - loss: 1.1199 - val_accuracy: 0.5736 - val_loss: 1.1175
# Epoch 73/100
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 46s 51ms/step - accuracy: 0.5790 - loss: 1.1156 - val_accuracy: 0.6177 - val_loss: 1.0168
# Epoch 74/100
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 46s 51ms/step - accuracy: 0.5735 - loss: 1.1226 - val_accuracy: 0.5936 - val_loss: 1.0824
# Epoch 75/100
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 46s 52ms/step - accuracy: 0.5740 - loss: 1.1240 - val_accuracy: 0.6216 - val_loss: 1.0139
# Epoch 76/100
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 46s 51ms/step - accuracy: 0.5863 - loss: 1.1085 - val_accuracy: 0.6194 - val_loss: 1.0267
# Epoch 77/100
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 46s 51ms/step - accuracy: 0.5796 - loss: 1.1169 - val_accuracy: 0.6109 - val_loss: 1.0268
# Epoch 78/100
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 46s 51ms/step - accuracy: 0.5794 - loss: 1.1055 - val_accuracy: 0.5906 - val_loss: 1.0827
